# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from geopy.exc import GeocoderTimedOut 
from geopy.geocoders import Nominatim

# %matplotlib inline

# %%
#import NDC deliveries csv
ndc_partner_del = pd.read_csv('../data/ndc_deliveries.csv')
print(ndc_partner_del.shape)
ndc_partner_del.head()
# Out:
# (108, 5)
#                 Partners                                  Address  Longitude  \
# 0      10th & Fatherland  1000 Fatherland St, Nashville, TN 37206 -86.739866
# 1  Alex Green Elementary     3921 Lloyd Road, Nashville, TN 37189 -86.835791
# 2    Antioch High School      1900 Hobson Pike, Antioch, TN 37013 -86.598459
# 3  Antioch Middle School     5050 Blue Hole Rd, Antioch, TN 37013 -86.672124
# 4   Apollo Middle School     631 Richards Rd, Nashville, TN 37013 -86.673096
#
#     Latitude  Total
# 0  36.173157   3500
# 1  36.252676   2250
# 2  36.047051  82250
# 3  36.059970   3100
# 4  36.068438   5150

# %%
ndc_map = folium.Map(
    location=[36.174465,-86.767960],
    zoom_start=10,
    tiles='Stamen Terrain'
)

#folium.LayerControl().add_to(ndc_map)
# inside the loop add each marker to the cluster
#for row_index, row_values in ndc_deliveries.iterrows():
#    loc = [row_values['Latitude'], row_values['Longitude']]
#    pop = '<b>Partner:</b> ' + str(row_values['Partners']) + ' ' + '<b>Diapers Delivered:</b> ' + str(row_values['Total'])
#    icon=folium.Icon(color="red",icon="info", prefix='fa')
    
#    marker = folium.Marker(
#        location = loc, 
#        popup = pop,
#    icon = icon) 
    
#    marker.add_to(marker_cluster)
                                                                                          
for ind, row in ndc_partner_del.iterrows():
    point = [row['Latitude'], row['Longitude']]
    popup = '<b>Partner:</b> ' + str(row['Partners']) + ' ' + '<b>Diapers Delivered:</b> ' + str(row['Total'])
    folium.CircleMarker(point, popup = popup, radius=5, fill=True, color='black').add_to(ndc_map)

ndc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
