# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from geopy.exc import GeocoderTimedOut 
from geopy.geocoders import Nominatim

# %matplotlib inline

# %% [markdown]
# ### Merge NDC Deliveries with NDC Partners to get Partners, Addresses, and Total Diaper Deliveries to be used in a map

# %%
#import NDC deliveries csv
deliveries = pd.read_csv('../data/Nash Diaper Stastistics - 2020 Deliveries.csv')
print(deliveries.shape)
deliveries.head()
# Out:
# (766, 16)
#                     Partners      Date      NB       1       2       3  \
# 0  NICE Highlands Apartments  1/4/2020   500.0   400.0   450.0   600.0
# 1             Martha O'Bryan  1/7/2020     NaN     NaN     NaN     NaN
# 2   Madison Hispanic 7th Day  1/7/2020     NaN     NaN   450.0   450.0
# 3     Legacy Mission Village  1/7/2020  1000.0  1000.0  1600.0  2375.0
# 4        Tusculum Elementary  1/7/2020   150.0   175.0   150.0   150.0
#
#         4       5       6 Pullups    Total  Running Total  Ever to Date  \
# 0   600.0   600.0   600.0     NaN   3750.0         3750.0     2321750.0
# 1   600.0   600.0   600.0     NaN   1800.0         5550.0     2323550.0
# 2   500.0   750.0   750.0     NaN   2900.0         8450.0     2326450.0
# 3  4500.0  4800.0  4800.0     NaN  20075.0        28525.0     2346525.0
# 4   150.0   150.0   150.0     NaN   1075.0        29600.0     2347600.0
#
#   Year to Date Unnamed: 14 Unnamed: 15
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN       2,900         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN

# %%
#import NDC deliveries csv
partners = pd.read_csv('../data/Nash Diaper Stastistics - 2020 Partner Agencies.csv')
print(partners.shape)
partners.head()
# Out:
# (116, 2)
#                  Partner                                      Address
# 0  Alex Green Elementary         3921 Lloyd Road, Nashville, TN 37189
# 1    Antioch High School          1900 Hobson Pike, Antioch, TN 37013
# 2     Catholic Charities        2806 McGavock Pk, Nashville, TN 37214
# 3        Cole Elementary          5060 Colemont Dr, Antioch, TN 37013
# 4  Connectus Priest Lake  2637 Murfreesboro Pike, Nashville, TN 37217

# %%
partners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Partner  116 non-null    object
#  1   Address  113 non-null    object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
# declare an empty list to store 
# latitude and longitude of values  
# of city column 
longitude = [] 
latitude = [] 
   
# function to find the coordinate 
# of a given address  
def findGeocode(address): 
       
    # try and catch is used to overcome 
    # the exception thrown by geolocator 
    # using geocodertimedout   
    try: 
          
        # Specify the user_agent as your 
        # app name it should not be none 
        geolocator = Nominatim(user_agent="paul") 
          
        return geolocator.geocode(address) 
      
    except GeocoderTimedOut: 
          
        return findGeocode(address)     
  
# each value from address column 
# will be fetched and sent to 
# function find_geocode    
for i in (partners['Address']): 
      
    if findGeocode(i) != None: 
           
        loc = findGeocode(i) 
          
        # coordinates returned from  
        # function is stored into 
        # two separate list 
        latitude.append(loc.latitude) 
        longitude.append(loc.longitude) 
       
    # if coordinate for a city not 
    # found, insert "NaN" indicating  
    # missing value  
    else: 
        latitude.append('NaN') 
        longitude.append('NaN') 
#Showing the output produced as dataframe.

#filter_none
#brightness_4
# now add this column to dataframe 
partners["Longitude"] = longitude 
partners["Latitude"] = latitude 
  
partners.head()
# Out:
#                  Partner                                      Address  \
# 0  Alex Green Elementary         3921 Lloyd Road, Nashville, TN 37189
# 1    Antioch High School          1900 Hobson Pike, Antioch, TN 37013
# 2     Catholic Charities        2806 McGavock Pk, Nashville, TN 37214
# 3        Cole Elementary          5060 Colemont Dr, Antioch, TN 37013
# 4  Connectus Priest Lake  2637 Murfreesboro Pike, Nashville, TN 37217
#
#   Longitude Latitude
# 0  -86.8358  36.2527
# 1  -86.5985  36.0471
# 2  -86.6799  36.1689
# 3  -86.6952  36.0607
# 4  -86.6669  36.1036

# %%
#merge the two files to get addresses for partners
ndc_deliveries = pd.merge(deliveries, partners, left_on = 'Partners', right_on = 'Partner', how = 'left')
ndc_deliveries.head()
# Out:
#                     Partners      Date      NB       1       2       3  \
# 0  NICE Highlands Apartments  1/4/2020   500.0   400.0   450.0   600.0
# 1             Martha O'Bryan  1/7/2020     NaN     NaN     NaN     NaN
# 2   Madison Hispanic 7th Day  1/7/2020     NaN     NaN   450.0   450.0
# 3     Legacy Mission Village  1/7/2020  1000.0  1000.0  1600.0  2375.0
# 4        Tusculum Elementary  1/7/2020   150.0   175.0   150.0   150.0
#
#         4       5       6 Pullups    Total  Running Total  Ever to Date  \
# 0   600.0   600.0   600.0     NaN   3750.0         3750.0     2321750.0
# 1   600.0   600.0   600.0     NaN   1800.0         5550.0     2323550.0
# 2   500.0   750.0   750.0     NaN   2900.0         8450.0     2326450.0
# 3  4500.0  4800.0  4800.0     NaN  20075.0        28525.0     2346525.0
# 4   150.0   150.0   150.0     NaN   1075.0        29600.0     2347600.0
#
#   Year to Date Unnamed: 14 Unnamed: 15                    Partner  \
# 0          NaN         NaN         NaN  NICE Highlands Apartments
# 1          NaN         NaN         NaN             Martha O'Bryan
# 2          NaN       2,900         NaN   Madison Hispanic 7th Day
# 3          NaN         NaN         NaN     Legacy Mission Village
# 4          NaN         NaN         NaN        Tusculum Elementary
#
#                                       Address Longitude Latitude
# 0  4646 Nolensville Pike, Nashville, TN 37211  -86.7236  36.0714
# 1           711 S 7th St, Nashville, TN 37206  -86.7606   36.174
# 2    1605 Neelys Bend Rd, Nashville, TN 37115  -86.7038  36.2554
# 3  5123 Nolensville Pike, Nashville, TN 37211  -86.7236  36.0714
# 4        440 McMurray Dr, Nashville, TN 37211  -86.7225  36.0589

# %%
ndc_deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 769 entries, 0 to 768
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Partners       769 non-null    object
#  1   Date           765 non-null    object
#  2   NB             721 non-null    float64
#  3   1              723 non-null    float64
#  4   2              733 non-null    float64
#  5   3              742 non-null    float64
#  6   4              747 non-null    float64
#  7   5              753 non-null    float64
#  8   6              749 non-null    float64
#  9   Pullups        18 non-null     object
#  10  Total          765 non-null    float64
#  11  Running Total  766 non-null    float64
#  12  Ever to Date   766 non-null    float64
#  13  Year to Date   44 non-null     object
#  14  Unnamed: 14    56 non-null     object
#  15  Unnamed: 15    18 non-null     object
#  16  Partner        769 non-null    object
#  17  Address        763 non-null    object
#  18  Longitude      769 non-null    object
#  19  Latitude       769 non-null    object
# dtypes: float64(10), object(10)
# memory usage: 126.2+ KB

# %%
#check for null addresses
ndc_deliveries[ndc_deliveries['Address'].isnull()]
# Out:
#                             Partners       Date     NB       1       2  \
# 67   Team Music Is Love One Gen Away   3/6/2020  900.0  1050.0  1000.0
# 148                   Salvation Army   4/6/2020    0.0     0.0   250.0
# 294                    Andrea Hollis  5/15/2020    0.0     0.0     0.0
# 392                    Andrea Hollis  6/15/2020    NaN     NaN     NaN
# 489                    Andrea Hollis  7/17/2020    NaN     NaN     NaN
# 580                    Andrea Hollis   9/2/2020    NaN     NaN     NaN
#
#           3      4      5      6 Pullups   Total  Running Total  Ever to Date  \
# 67   1600.0  800.0  825.0  750.0     NaN  6925.0        69559.0     2532824.0
# 148   250.0  150.0  250.0  200.0     NaN  1100.0        38800.0     2700105.0
# 294     0.0   46.0    0.0    0.0     NaN    46.0       127978.0     3010758.0
# 392     NaN  100.0    NaN    NaN     NaN   100.0       112223.0     3230719.0
# 489     NaN  150.0    NaN    NaN     NaN   150.0       111735.0     3457726.0
# 580     NaN   50.0    NaN    NaN     NaN    50.0        17325.0     3726846.0
#
#     Year to Date Unnamed: 14 Unnamed: 15                          Partner  \
# 67           NaN         NaN         NaN  Team Music Is Love One Gen Away
# 148          NaN         NaN         NaN                   Salvation Army
# 294          NaN         NaN         NaN                    Andrea Hollis
# 392          NaN         NaN         NaN                    Andrea Hollis
# 489    1,141,076      32,945         NaN                    Andrea Hollis
# 580          NaN         NaN         NaN                    Andrea Hollis
#
#     Address Longitude Latitude
# 67      NaN    11.048  46.3145
# 148     NaN    11.048  46.3145
# 294     NaN    11.048  46.3145
# 392     NaN    11.048  46.3145
# 489     NaN    11.048  46.3145
# 580     NaN    11.048  46.3145

# %%
#drop rows with null addresses
ndc_deliveries=ndc_deliveries.dropna(subset=['Address'])
ndc_deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763 entries, 0 to 768
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Partners       763 non-null    object
#  1   Date           759 non-null    object
#  2   NB             718 non-null    float64
#  3   1              720 non-null    float64
#  4   2              730 non-null    float64
#  5   3              739 non-null    float64
#  6   4              741 non-null    float64
#  7   5              750 non-null    float64
#  8   6              746 non-null    float64
#  9   Pullups        18 non-null     object
#  10  Total          759 non-null    float64
#  11  Running Total  760 non-null    float64
#  12  Ever to Date   760 non-null    float64
#  13  Year to Date   43 non-null     object
#  14  Unnamed: 14    55 non-null     object
#  15  Unnamed: 15    18 non-null     object
#  16  Partner        763 non-null    object
#  17  Address        763 non-null    object
#  18  Longitude      763 non-null    object
#  19  Latitude       763 non-null    object
# dtypes: float64(10), object(10)
# memory usage: 125.2+ KB

# %%
#only keep certain columns
#ndc_deliveries = ndc_deliveries[['Partners', 'Address', 'Total', 'Longitude', 'Latitude']].copy()
#ndc_deliveries.head()
# Out:
#                     Partners                                     Address  \
# 0  NICE Highlands Apartments  4646 Nolensville Pike, Nashville, TN 37211
# 1             Martha O'Bryan           711 S 7th St, Nashville, TN 37206
# 2   Madison Hispanic 7th Day    1605 Neelys Bend Rd, Nashville, TN 37115
# 3     Legacy Mission Village  5123 Nolensville Pike, Nashville, TN 37211
# 4        Tusculum Elementary        440 McMurray Dr, Nashville, TN 37211
#
#      Total
# 0   3750.0
# 1   1800.0
# 2   2900.0
# 3  20075.0
# 4   1075.0

# %%
#group by Partners and add values in total column
ndc_deliveries = ndc_deliveries.groupby(['Partners','Address'], as_index=False)['Total'].sum()
ndc_deliveries
# Out:
#                                 Partners  \
# 0                      10th & Fatherland
# 1                  Alex Green Elementary
# 2                    Antioch High School
# 3                  Antioch Middle School
# 4                   Apollo Middle School
# ..                                   ...
# 104             Whites Creek High School
# 105                  Whitsitt Elementary
# 106  Wilson County Community Help Center
# 107              Woodmont Baptist Church
# 108                                 YWCA
#
#                                            Address    Total
# 0          1000 Fatherland St, Nashville, TN 37206   3500.0
# 1             3921 Lloyd Road, Nashville, TN 37189   2250.0
# 2              1900 Hobson Pike, Antioch, TN 37013  82250.0
# 3             5050 Blue Hole Rd, Antioch, TN 37013   3100.0
# 4             631 Richards Rd, Nashville, TN 37013   5150.0
# ..                                             ...      ...
# 104  7277 Old Hickory Blvd, Whites Creek, TN 37189   2450.0
# 105           110 Whitsett Rd, Nashville, TN 37210   1100.0
# 106               203 W High St, Lebanon, TN 37087   2450.0
# 107        2100 Woodmond Blvd, Nashville, TN 37215   3300.0
# 108        1608 Woodmont Blvd, Nashville, TN 37215   3589.0
#
# [109 rows x 3 columns]

# %%
#export as csv
#partner_totals=partners.to_csv('partner_totals.csv', index = False)

# %%
#export as csv
#ndc_deliveries=ndc_deliveries.to_csv('ndc_deliveries.csv', index = False)
