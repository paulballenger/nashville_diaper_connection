# %% [markdown]
# ## Create final plot showing remaining need, based on ndc children served compared to estimated children <4 in TennCare.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
#import NDC deliveries csv
county_stats = pd.read_csv('../files/county_stats.csv')
county_stats.head()
# Out:
#        County Total Population Population Age 0-4 Population Age 5-9  \
# 0    Davidson          667,885             46,539             41,537
# 1  Williamson          205,645             12,451             16,755
# 2  Montgomery          189,709             16,476             14,404
# 3       Maury           85,767              5,730              6,077
# 4     Hickman           24,251              1,291              1,553
#
#   Population Age 0-9 # Households # Live Births Est # in Diapers  \
# 0             88,076      269,078         9,962           24,905
# 1             29,206       71,043         2,321            5,803
# 2             30,880       67,090         3,512            8,780
# 3             11,807       32,889         1,184            2,960
# 4              2,844        8,855           257              643
#
#   Est. TennCare Household Income (Avg) % Title 1 Schools % Food Stamp  \
# 0        12,453               $60,388             63.42%       14.60%
# 1         2,901              $112,962             17.74%        3.40%
# 2         4,390               $57,541             61.70%       13.20%
# 3         1,480               $57,170             64.20%       16.40%
# 4           321               $43,596             88.89%       22.70%
#
#   % Poverty Rate 0-17 % Poverty Rate All Ages  Pop in Poverty <17  \
# 0              25.40%                  15.40%              169643
# 1               3.50%                   3.80%                7198
# 2              16.60%                  12.00%               31492
# 3              15.20%                  10.80%               13037
# 4              24.20%                  16.30%                5869
#
#    Pop in Poverty Tot  In Diapers in Poverty  diapers used Diaper cost/month  \
# 0              102854               6325.870    1518208.80           $80.00
# 1                7815                203.105      48745.20           $80.00
# 2               22765               1457.480     349795.20           $80.00
# 3                9263                449.920     107980.80           $80.00
# 4                3953                155.606      37345.44           $80.00
#
#   $ per county/month for low income
# 0                      $442,810.90
# 1                       $14,217.35
# 2                      $102,023.60
# 3                       $31,494.40
# 4                       $10,892.42

# %%
#only keep needed columns
county_stats = county_stats[['County',
                             'Population Age 0-4',
                             'Est # in Diapers',
                             'Est. TennCare',
                             'In Diapers in Poverty',
                             'diapers used'
                            ]].copy()
county_stats.head()
# Out:
#        County Population Age 0-4 Est # in Diapers Est. TennCare  \
# 0    Davidson             46,539           24,905        12,453
# 1  Williamson             12,451            5,803         2,901
# 2  Montgomery             16,476            8,780         4,390
# 3       Maury              5,730            2,960         1,480
# 4     Hickman              1,291              643           321
#
#    In Diapers in Poverty  diapers used
# 0               6325.870    1518208.80
# 1                203.105      48745.20
# 2               1457.480     349795.20
# 3                449.920     107980.80
# 4                155.606      37345.44

# %%
#rename columns
county_stats = county_stats.rename(columns = {'County':'county',
                                              'Population Age 0-4':'pop_under_4',
                                              'Est # in Diapers':'est_in_diapers',
                                              'Est. TennCare':'est_in_tenncare',
                                              'In Diapers in Poverty':'diapers_and_poverty',
                                              'diapers used':'diapers_used'
                                             })
county_stats.columns
# Out:
# Index(['county', 'pop_under_4', 'est_in_diapers', 'est_in_tenncare',
#        'diapers_and_poverty', 'diapers_used'],
#       dtype='object')

# %%
#import NDC deliveries csv
total_by_county = pd.read_csv('../files/total_by_county.csv')
total_by_county.head()
# Out:
#            County    Total
# 0    Davidson, TN  1817313
# 1    Marshall, TN     2025
# 2       Maury, TN     1475
# 3  Washington, TN     3750
# 4  Williamson, TN     6050

# %%
#strip TN from counties and rename
total_by_county['County'] = total_by_county['County'].str.strip(', TN')
total_by_county = total_by_county.rename(columns = {'County':'county',
                                              'Total':'total'
                                             })
total_by_county
# Out:
#        county    total
# 0    Davidson  1817313
# 1    Marshall     2025
# 2       Maury     1475
# 3  Washington     3750
# 4  Williamson     6050
# 5      Wilson    10550
# 6        otal  1841163
